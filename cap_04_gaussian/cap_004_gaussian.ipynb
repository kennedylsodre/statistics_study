# %%
from numpy import arange 
import matplotlib.pyplot as plt 
from scipy.stats import norm
from numpy.random import seed,randn

# %% [markdown]
# A curva de distribuição normal mostra no eixo X a observação e no eixo Y a probabilidade de cada observação.

# %%
#Plotando uma curva normal 
x_axis = arange(-3,3,0.001)
y_axis = norm.pdf(x_axis, 0, 1) 

plt.plot(x_axis,y_axis)

# %%
#setando seed 
seed(1)

#Gerando observações 
data = 5*randn (1000) + 50 

#plotando o histograma 
plt.hist(data)
# Out:
# (array([ 10.,  37., 103., 223., 286., 224.,  90.,  24.,   1.,   2.]),
#  array([34.7311781 , 38.23736164, 41.74354518, 45.24972872, 48.75591227,
#         52.26209581, 55.76827935, 59.27446289, 62.78064644, 66.28682998,
#         69.79301352]),
#  <BarContainer object of 10 artists>)
